# %% [markdown]
# # Guelph
#
# ## City
# https://explore.guelph.ca/
#
# https://www.guelphpolice.ca/en/about-gps/open-data.aspx#
#
# https://guides.lib.uoguelph.ca/opendata
#
# ## County
#
# https://www.wellington.ca/business-development/invest-wellington/wellington-county-data
#
# ## Province
# https://geohub.lio.gov.on.ca/
#
# ## Country
#
# https://open.canada.ca/en

# %% [markdown]
# # Vancouver Metro
#
# ## City
#
# https://opendata.vancouver.ca/pages/home/
#
# https://data.burnaby.ca/
#
# https://www.surrey.ca/services-payments/online-services/open-data
#
# https://data.coquitlam.ca/
#
# https://www.richmond.ca/services/digital/maps.htm
#
# https://mapping.westvancouver.ca/OD/dbo_OPENDATA_FILES_list.php?page=list
#
# https://www.dnv.org/government-administration/open-data-geoweb
#
# https://www.whiterockcity.ca/345/Open-Data
#
# ## County
#
# https://metrovancouver.org/
#
# ## Province
#
# https://www2.gov.bc.ca/gov/content/data/finding-and-sharing/bc-data-catalogue
#
# ## Country
#
# https://open.canada.ca/en
