# %% [markdown]
# # Can Vancouver Feed Itself?
#
# If civilization collapses, can Vancouver feed itself within its own border?
#
# Sources:
# - https://www12.statcan.gc.ca/census-recensement/2021/dp-pd/prof/details/download-telecharger.cfm?Lang=E
# - https://www150.statcan.gc.ca/n1/en/catalogue/982600032021001
# - https://www12.statcan.gc.ca/census-recensement/2021/geo/maps-cartes/referencemaps-cartesdereference/index2021-eng.cfm

# %%
import numpy as np
import pandas as pd

# %%
# read census of provinces and territories into a small, meaningful dataset
useful_columns = ['DGUID', 'CENSUS_YEAR', 'GEO_LEVEL', 'GEO_NAME', 'CHARACTERISTIC_ID',
       'CHARACTERISTIC_NAME', 'C1_COUNT_TOTAL']
#useful_characteristic_ids = [1, 2, 6, 7, 1522, 1523, 1526, 1527, 1528, 1529, 1537]
useful_characteristic_ids = [1, 2, 6, 7]

CALORIES_PER_PERSON_PER_DAY = 2000
DAYS_PER_YEAR = 365

# %%
# read hierarchy of territorial divisions

# Reference guide for Dissemination Geographics Relationship File
# https://www150.statcan.gc.ca/n1/pub/98-26-0003/982600032021001-eng.htm

# Province and Territory, Census Division, Census Subdivision, Economic Region
hierarchy_useful_columns = ["PRDGUID_PRIDUGD", "CDDGUID_DRIDUGD", "CSDDGUID_SDRIDUGD", "ERDGUID_REIDUGD"]

# 2021 Census – Dissemination Geographies Relationship File
# https://www12.statcan.gc.ca/census-recensement/2021/geo/sip-pis/dguid-idugd/index2021-eng.cfm?year=21
hierarchy_df = pd.read_csv('2021_98260004.csv', usecols=hierarchy_useful_columns).drop_duplicates()

er_map_df = hierarchy_df[["PRDGUID_PRIDUGD", "ERDGUID_REIDUGD"]].drop_duplicates()

cd_map_df = hierarchy_df[["PRDGUID_PRIDUGD", "ERDGUID_REIDUGD", "CDDGUID_DRIDUGD"]].drop_duplicates()

csd_map_df = hierarchy_df[["PRDGUID_PRIDUGD", "ERDGUID_REIDUGD", "CDDGUID_DRIDUGD", "CSDDGUID_SDRIDUGD"]].drop_duplicates()

# %%
# 2021 Census - Reference Maps
# https://www12.statcan.gc.ca/census-recensement/2021/dp-pd/prof/details/download-telecharger.cfm?Lang=E
# 2021 Census - Standard Geographical Classification (SGC) reference maps
def get_bc_province_census_df():

    df = pd.read_csv('./ca_provinces_census/98-401-X2021001_English_CSV_data.csv', encoding='utf-8', encoding_errors='replace', usecols=useful_columns)
    
    # filter only by useful characteristic ids
    
    ca_df = df[df['CHARACTERISTIC_ID'].isin(useful_characteristic_ids) & (df['GEO_NAME'] == 'Canada')]
    province_df = df[df['CHARACTERISTIC_ID'].isin(useful_characteristic_ids) & (df['GEO_NAME'] != 'Canada')]
    bc_df = df[df['CHARACTERISTIC_ID'].isin(useful_characteristic_ids) & (df['GEO_NAME'] == 'British Columbia')]
    
    del df

    return bc_df

# %%
# https://www12.statcan.gc.ca/census-recensement/2021/dp-pd/prof/details/download-telecharger.cfm?Lang=E
def get_bc_census_division_census_df(cd_map_df, bc_df):

    # read census of census divisions into a small, meaningful dataset
    useful_columns = ['DGUID', 'CENSUS_YEAR', 'GEO_LEVEL', 'GEO_NAME', 'CHARACTERISTIC_ID',
           'CHARACTERISTIC_NAME', 'C1_COUNT_TOTAL']
    
    df = pd.read_csv('./ca_cd_census/98-401-X2021004_English_CSV_data.csv', encoding='utf-8', encoding_errors='replace', usecols=useful_columns)
    
    #useful_characteristic_ids = [1, 2, 6, 7, 1522, 1523, 1526, 1527, 1528, 1529, 1537]
    useful_characteristic_ids = [1, 2, 6, 7]
    
    ca_cd_df = df[df['CHARACTERISTIC_ID'].isin(useful_characteristic_ids)]
    
    del df

    bc_province_dguid = bc_df["DGUID"].unique()[0]

    bc_cd_dguids = cd_map_df.loc[cd_map_df["PRDGUID_PRIDUGD"] == bc_province_dguid, 'CDDGUID_DRIDUGD'].values

    bc_cd_df = ca_cd_df[ca_cd_df["DGUID"].isin(bc_cd_dguids)]

    return bc_cd_df

# %%
# https://www12.statcan.gc.ca/census-recensement/2021/dp-pd/prof/details/download-telecharger.cfm?Lang=E
def get_bc_census_subdivision_census_df():
    # read census of census subdivisions in BC into a small, meaningful dataset
    
    df = pd.read_csv('./ca_bc_csd_census/98-401-X2021025_English_CSV_data.csv', encoding='utf-8', encoding_errors='replace', usecols=useful_columns)
    
    bc_csd_df = df[df['CHARACTERISTIC_ID'].isin(useful_characteristic_ids)]
    
    del df

    return bc_csd_df

# %%
# https://www12.statcan.gc.ca/census-recensement/2021/dp-pd/prof/details/download-telecharger.cfm?Lang=E
def get_bc_economic_regions_census_df(er_map_df, bc_province_df):

    df = pd.read_csv('./ca_er_census/98-401-X2021008_English_CSV_data.csv', encoding='utf-8', encoding_errors='replace', usecols=useful_columns)
    
    ca_er_df = df[df['CHARACTERISTIC_ID'].isin(useful_characteristic_ids)]
    
    del df

    bc_province_dguid = bc_province_df["DGUID"].unique()[0]

    bc_cd_dguids = er_map_df.loc[er_map_df["PRDGUID_PRIDUGD"] == bc_province_dguid, 'ERDGUID_REIDUGD'].values

    bc_er_df = ca_er_df[ca_er_df["DGUID"].isin(bc_cd_dguids)]

    return bc_er_df

# %%
bc_province_df = get_bc_province_census_df()

bc_cd_df = get_bc_census_division_census_df(cd_map_df, bc_province_df)

bc_csd_df = get_bc_census_subdivision_census_df()

bc_er_df = get_bc_economic_regions_census_df(er_map_df, bc_province_df)

# get the greater vancouver census divisions

greater_vancouver_cd_df =  bc_cd_df.loc[bc_cd_df["GEO_NAME"] == "Greater Vancouver, Regional district (RD)"]

greater_vancouver_cd_dguid = bc_cd_df.loc[bc_cd_df["GEO_NAME"] == "Greater Vancouver, Regional district (RD)", "DGUID"].unique()[0]

# get the greater vancouver census division ID to get the census subdivisions within BC

greater_vancouver_csd_dguids = csd_map_df.loc[csd_map_df["CDDGUID_DRIDUGD"] == greater_vancouver_cd_dguid, 'CSDDGUID_SDRIDUGD'].values

greater_vancouver_csd_df = bc_csd_df[bc_csd_df["DGUID"].isin(greater_vancouver_csd_dguids)]

# %%
# its also good to know about the economic region that greater vancouver is in, the Lower Mainland - Southwest Economic Region

lower_mainland_er_dguid = bc_er_df.loc[bc_er_df["GEO_NAME"] == "Lower Mainland--Southwest", "DGUID"].unique()[0]

# now, check the hierarchy dataframe for the census divison dguids that are in the lower mainland
lower_mainland_cd_dguids = hierarchy_df.loc[hierarchy_df["ERDGUID_REIDUGD"] == lower_mainland_er_dguid, "CDDGUID_DRIDUGD"].unique()

lower_mainland_cd_df = bc_cd_df.loc[bc_cd_df["DGUID"].isin(lower_mainland_cd_dguids)]

# %%
greater_vancouver_cd_df
# Out:
#         CENSUS_YEAR          DGUID        GEO_LEVEL  \
# 681429         2021  2021A00035915  Census division
# 681430         2021  2021A00035915  Census division
# 681434         2021  2021A00035915  Census division
# 681435         2021  2021A00035915  Census division
#
#                                          GEO_NAME  CHARACTERISTIC_ID  \
# 681429  Greater Vancouver, Regional district (RD)                  1
# 681430  Greater Vancouver, Regional district (RD)                  2
# 681434  Greater Vancouver, Regional district (RD)                  6
# 681435  Greater Vancouver, Regional district (RD)                  7
#
#                             CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 681429                         Population, 2021      2642825.00
# 681430                         Population, 2016      2463431.00
# 681434  Population density per square kilometre          918.00
# 681435           Land area in square kilometres         2878.93

# %%
greater_vancouver_csd_df
# Out:
#         CENSUS_YEAR             DGUID           GEO_LEVEL  \
# 378864         2021  2021A00055915001  Census subdivision
# 378865         2021  2021A00055915001  Census subdivision
# 378869         2021  2021A00055915001  Census subdivision
# 378870         2021  2021A00055915001  Census subdivision
# 381495         2021  2021A00055915002  Census subdivision
# ...             ...               ...                 ...
# 473586         2021  2021A00055915830  Census subdivision
# 476211         2021  2021A00055915840  Census subdivision
# 476212         2021  2021A00055915840  Census subdivision
# 476216         2021  2021A00055915840  Census subdivision
# 476217         2021  2021A00055915840  Census subdivision
#
#                                    GEO_NAME  CHARACTERISTIC_ID  \
# 378864  Langley, District municipality (DM)                  1
# 378865  Langley, District municipality (DM)                  2
# 378869  Langley, District municipality (DM)                  6
# 378870  Langley, District municipality (DM)                  7
# 381495                   Langley, City (CY)                  1
# ...                                     ...                ...
# 473586       Katzie 1, Indian reserve (IRI)                  7
# 476211     Whonnock 1, Indian reserve (IRI)                  1
# 476212     Whonnock 1, Indian reserve (IRI)                  2
# 476216     Whonnock 1, Indian reserve (IRI)                  6
# 476217     Whonnock 1, Indian reserve (IRI)                  7
#
#                             CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 378864                         Population, 2021       132603.00
# 378865                         Population, 2016       117285.00
# 378869  Population density per square kilometre          431.60
# 378870           Land area in square kilometres          307.22
# 381495                         Population, 2021        28963.00
# ...                                         ...             ...
# 473586           Land area in square kilometres            0.42
# 476211                         Population, 2021            5.00
# 476212                         Population, 2016            0.00
# 476216  Population density per square kilometre           12.90
# 476217           Land area in square kilometres            0.39
#
# [152 rows x 7 columns]

# %%
# Characteristic ID 1: Population, 2021
# Characteristic ID 6: Population density per square kilometre
# Characteristic ID 7: Land are in square kilometres

greater_vancouver_csd_df[greater_vancouver_csd_df["CHARACTERISTIC_ID"] == 6].sort_values("C1_COUNT_TOTAL")
# Out:
#         CENSUS_YEAR             DGUID           GEO_LEVEL  \
# 444644         2021  2021A00055915804  Census subdivision
# 476216         2021  2021A00055915840  Census subdivision
# 460430         2021  2021A00055915810  Census subdivision
# 394655         2021  2021A00055915020  Census subdivision
# 436751         2021  2021A00055915801  Census subdivision
# 468323         2021  2021A00055915816  Census subdivision
# 465692         2021  2021A00055915813  Census subdivision
# 426227         2021  2021A00055915062  Census subdivision
# 410441         2021  2021A00055915038  Census subdivision
# 407810         2021  2021A00055915036  Census subdivision
# 463061         2021  2021A00055915811  Census subdivision
# 431489         2021  2021A00055915070  Census subdivision
# 434120         2021  2021A00055915075  Census subdivision
# 439382         2021  2021A00055915802  Census subdivision
# 378869         2021  2021A00055915001  Census subdivision
# 423596         2021  2021A00055915055  Census subdivision
# 418334         2021  2021A00055915046  Census subdivision
# 428858         2021  2021A00055915065  Census subdivision
# 473585         2021  2021A00055915830  Census subdivision
# 389393         2021  2021A00055915011  Census subdivision
# 442013         2021  2021A00055915803  Census subdivision
# 405179         2021  2021A00055915034  Census subdivision
# 415703         2021  2021A00055915043  Census subdivision
# 392024         2021  2021A00055915015  Census subdivision
# 470954         2021  2021A00055915825  Census subdivision
# 455168         2021  2021A00055915808  Census subdivision
# 447275         2021  2021A00055915805  Census subdivision
# 384131         2021  2021A00055915004  Census subdivision
# 452537         2021  2021A00055915807  Census subdivision
# 413072         2021  2021A00055915039  Census subdivision
# 449906         2021  2021A00055915806  Census subdivision
# 399917         2021  2021A00055915025  Census subdivision
# 381500         2021  2021A00055915002  Census subdivision
# 386762         2021  2021A00055915007  Census subdivision
# 420965         2021  2021A00055915051  Census subdivision
# 402548         2021  2021A00055915029  Census subdivision
# 397286         2021  2021A00055915022  Census subdivision
# 457799         2021  2021A00055915809  Census subdivision
#
#                                                  GEO_NAME  CHARACTERISTIC_ID  \
# 444644                  Coquitlam 2, Indian reserve (IRI)                  6
# 476216                   Whonnock 1, Indian reserve (IRI)                  6
# 460430                   Musqueam 4, Indian reserve (IRI)                  6
# 394655  Metro Vancouver A, Regional district electoral...                  6
# 436751                    Semiahmoo, Indian reserve (IRI)                  6
# 468323            McMillan Island 6, Indian reserve (IRI)                  6
# 465692                     Katzie 2, Indian reserve (IRI)                  6
# 426227             Bowen Island, Island municipality (IM)                  6
# 410441                               Anmore, Village (VL)                  6
# 407810                             Belcarra, Village (VL)                  6
# 463061              Seymour Creek 2, Indian reserve (IRI)                  6
# 431489                            Pitt Meadows, City (CY)                  6
# 434120                             Maple Ridge, City (CY)                  6
# 439382                 Tsawwassen, Tsawwassen Lands (TWL)                  6
# 378869                Langley, District municipality (DM)                  6
# 423596         West Vancouver, District municipality (DM)                  6
# 418334        North Vancouver, District municipality (DM)                  6
# 428858                            Lions Bay, Village (VL)                  6
# 473585                     Katzie 1, Indian reserve (IRI)                  6
# 389393                                   Delta, City (CY)                  6
# 442013                   Musqueam 2, Indian reserve (IRI)                  6
# 405179                               Coquitlam, City (CY)                  6
# 415703                              Port Moody, City (CY)                  6
# 392024                                Richmond, City (CY)                  6
# 470954                    Matsqui 4, Indian reserve (IRI)                  6
# 455168                   Capilano 5, Indian reserve (IRI)                  6
# 447275                  Coquitlam 1, Indian reserve (IRI)                  6
# 384131                                  Surrey, City (CY)                  6
# 452537                    Mission 1, Indian reserve (IRI)                  6
# 413072                          Port Coquitlam, City (CY)                  6
# 449906              Burrard Inlet 3, Indian reserve (IRI)                  6
# 399917                                 Burnaby, City (CY)                  6
# 381500                                 Langley, City (CY)                  6
# 386762                              White Rock, City (CY)                  6
# 420965                         North Vancouver, City (CY)                  6
# 402548                         New Westminster, City (CY)                  6
# 397286                               Vancouver, City (CY)                  6
# 457799            Barnston Island 3, Indian reserve (IRI)                  6
#
#                             CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 444644  Population density per square kilometre             0.0
# 476216  Population density per square kilometre            12.9
# 460430  Population density per square kilometre            18.8
# 394655  Population density per square kilometre            22.8
# 436751  Population density per square kilometre            53.7
# 468323  Population density per square kilometre            53.9
# 465692  Population density per square kilometre            84.6
# 426227  Population density per square kilometre            84.9
# 410441  Population density per square kilometre            85.6
# 407810  Population density per square kilometre           124.8
# 463061  Population density per square kilometre           216.0
# 431489  Population density per square kilometre           221.7
# 434120  Population density per square kilometre           339.7
# 439382  Population density per square kilometre           343.3
# 378869  Population density per square kilometre           431.6
# 423596  Population density per square kilometre           506.1
# 418334  Population density per square kilometre           548.8
# 428858  Population density per square kilometre           549.0
# 473585  Population density per square kilometre           575.3
# 389393  Population density per square kilometre           603.7
# 442013  Population density per square kilometre           894.7
# 405179  Population density per square kilometre          1216.7
# 415703  Population density per square kilometre          1297.3
# 392024  Population density per square kilometre          1629.0
# 470954  Population density per square kilometre          1654.6
# 455168  Population density per square kilometre          1689.1
# 447275  Population density per square kilometre          1774.2
# 384131  Population density per square kilometre          1797.9
# 452537  Population density per square kilometre          2060.0
# 413072  Population density per square kilometre          2108.7
# 449906  Population density per square kilometre          2123.3
# 399917  Population density per square kilometre          2750.7
# 381500  Population density per square kilometre          2845.2
# 386762  Population density per square kilometre          4240.6
# 420965  Population density per square kilometre          4913.0
# 402548  Population density per square kilometre          5052.4
# 397286  Population density per square kilometre          5749.9
# 457799  Population density per square kilometre             NaN

# %%
greater_vancouver_csd_df[(greater_vanBhinneka Tunggal Ikacouver_csd_df["CHARACTERISTIC_ID"] == 7) & greater_vancouver_csd_df["GEO_NAME"].str.contains("IRI")].sum()
# Out:
#   Cell In[13], line 1
#     greater_vancouver_csd_df[(greater_vanBhinneka Tunggal Ikacouver_csd_df["CHARACTERISTIC_ID"] == 7) & greater_vancouver_csd_df["GEO_NAME"].str.contains("IRI")].sum()
#                               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
